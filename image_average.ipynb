# %%
import cv2

# %%
IMG_P = '/run/media/neotod/joint/multimedia/photos/animals/cute_buddies.jpg'

img = cv2.cvtColor(cv2.imread(IMG_P), cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.imshow(img / 255)

# %%
import numpy as np

# %%
noisy_imgs

# %%
noisy_imgs = [img / 255 + np.random.randn(*img.shape) * 0.5 for _ in range(100)]

# %%
fig, ax = plt.subplots(2, 5, figsize=(5*5, 2*5))

for i, img in enumerate(noisy_imgs):
    ax[i // 5][i % 5].imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
avg_img = np.mean(noisy_imgs, axis=0)

# %%
plt.imshow(avg_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_neg = 1 - img
plt.imshow(img_neg)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

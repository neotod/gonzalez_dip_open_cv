# %%
import numpy as np
import cv2

# %%
img = cv2.cvtColor(cv2.imread('../lena.png'), cv2.COLOR_BGR2GRAY)

# %%
import matplotlib.pyplot as plt

# %%
plt.gray()

# %%
plt.imshow(img)

# %%
plt.hist([np.random.rand() for _ in range(1000)])
# Out:
# (array([114.,  80., 100., 114., 107., 104., 100.,  96.,  92.,  93.]),
#  array([1.87049551e-04, 9.99588280e-02, 1.99730607e-01, 2.99502385e-01,
#         3.99274163e-01, 4.99045942e-01, 5.98817720e-01, 6.98589499e-01,
#         7.98361277e-01, 8.98133056e-01, 9.97904834e-01]),
#  <BarContainer object of 10 artists>)

# %%
from random import randint

# %%
randint(1, 100)
# Out:
# 79

# %%
img.shape
# Out:
# (330, 330)

# %%
img_cp = img.copy()

for _ in range(10000):
    x, y = img_cp.shape
    
    img_cp[randint(0, x-1)][randint(0, y-1)] = 255
    img_cp[randint(0, x-1)][randint(0, y-1)] = 0

# %%
plt.imshow(img_cp)

# %%
from scipy.ndimage import median_filter

# %%
plt.imshow(median_filter(img_cp, 4))

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor( cv2.imread('../shaded_chb.png'), cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
img.shape
# Out:
# (455, 452)

# %%
import numpy as np

# %%
plt.hist(img.ravel(), bins=256);

# %%
plt.hist(eq_hist_img.ravel(), bins=256);

# %%
eq_hist_img = cv2.equalizeHist(img)

# %%
plt.imshow(eq_hist_img, cmap='gray')

# %%
eq_hist_img_2 = cv2.equalizeHist(eq_hist_img)

# %%
np.multiply(*eq_hist_img_2.shape)
# Out:
# 205660

# %%
np.sum(eq_hist_img == eq_hist_img_2)
# Out:
# 205660
